# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from sklearn.metrics import f1_score

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load in your data from kaggle.
# By working in a kaggle kernel, you can access the data directly from the competition, as well as make your submission without downloading your output file

# %%
train = pd.read_csv('../input/climate-change-edsa2020-21/train.csv')
test = pd.read_csv('../input/climate-change-edsa2020-21/test.csv')

# %%
train.sentiment.value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Splitting out the X variable from the target

# %%
y = train['sentiment']
X = train['message']

# %% [markdown]
# ## Turning text into something your model can read

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=3, stop_words="english")
X_vectorized = vectorizer.fit_transform(X)

# %% [markdown]
# ## Splitting the training data into a training and validation set

# %%
X_train,X_val,y_train,y_val = train_test_split(X_vectorized,y,test_size=.2,shuffle=True, stratify=y, random_state=27)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-125d2c2cb9c7> in <module>
# ----> 1 X_train,X_val,y_train,y_val = train_test_split(X_vectorized,y,test_size=2,shuffle=True, stratify=y, random_state=27)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2150                      random_state=random_state)
#    2151
# -> 2152         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2153
#    2154     return list(chain.from_iterable((_safe_indexing(a, train),
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1339         """
#    1340         X, y, groups = indexable(X, y, groups)
# -> 1341         for train, test in self._iter_indices(X, y, groups):
#    1342             yield train, test
#    1343
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1678             raise ValueError('The test_size = %d should be greater or '
#    1679                              'equal to the number of classes = %d' %
# -> 1680                              (n_test, n_classes))
#    1681
#    1682         # Find the sorted list of instances for each class:
#
# ValueError: The test_size = 2 should be greater or equal to the number of classes = 4

# %% [markdown]
# ## Training the model and evaluating using the validation set

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_val)

#DecisionTreeClassifier
#from sklearn.tree import DecisionTreeClassifier
#dts = DecisionTreeClassifier()
#dts.fit(X_train, y_train)
#dts_pred = dts.predict(X_val)

# %% [markdown]
# ## Checking the performance of our model on the validation set

# %%
f1_score(y_val, rfc_pred, average="macro")
# Out:
# 0.5618402802799544

# %% [markdown]
# ## Getting our test set ready

# %%
testx = test['message']
test_vect = vectorizer.transform(testx)

# %% [markdown]
# ## Making predictions on the test set and adding a sentiment column to our original test df

# %%
y_pred = rfc.predict(test_vect)

# %%
test['sentiment'] = y_pred

# %%
test.head()
# Out:
#                                              message  tweetid  sentiment
# 0  Europe will now be looking to China to make su...   169760          2
# 1  Combine this with the polling of staffers re c...    35326          1
# 2  The scary, unimpeachable evidence that climate...   224985          1
# 3  @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263          1
# 4  RT @FakeWillMoore: 'Female orgasms cause globa...   872928          0

# %% [markdown]
# ## Creating an output csv for submission

# %%
test[['tweetid','sentiment']].to_csv('testsubmission4.csv', index=False)
